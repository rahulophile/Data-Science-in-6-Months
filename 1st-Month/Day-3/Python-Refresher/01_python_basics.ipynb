# %%
x = 5

# %%
print(x)
# Out:
# 5

# %%
y = 6

# %%
x + y
# Out:
# 11

# %%
str = "Rahul"

# %%
print(str)
# Out:
# Rahul

# %%
# single line comment

# %%
'''HelloRahul'''
# Out:
# 'HelloRahul'

# %%
print(type(y))
# Out:
# <class 'int'>

# %%
a = "999"

# %%
b = "344"

# %%
print(a+b)
# Out:
# 999344

# %%
print(int(a) + int(b)) #called  typecasting
# Out:
# 1343
