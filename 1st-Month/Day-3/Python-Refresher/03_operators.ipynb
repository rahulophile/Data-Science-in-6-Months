# %%
a = 5

# %%
b = 2

# %%
a + b
# Out:
# 7

# %%
a /b
# Out:
# 2.5

# %%
a*b
# Out:
# 10

# %%
2**5
# Out:
# 32

# %%
a%b
# Out:
# 1

# %%
a<b
# Out:
# False

# %%
a<=b
# Out:
# False

# %%
a == b #is a equal to b
# Out:
# False

# %%
a != b #is a not equal to b
# Out:
# True
