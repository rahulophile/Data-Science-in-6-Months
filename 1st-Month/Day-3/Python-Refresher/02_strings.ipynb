# %%
name = "Rahul" #string

# %%
name
# Out:
# 'Rahul'

# %%
print(name)
# Out:
# Rahul

# %%
name.upper()
# Out:
# 'RAHUL'

# %%
name.endswith("ul")
# Out:
# True

# %%
name.lower()
# Out:
# 'rahul'

# %%
name.count("a")
# Out:
# 1

# %%
gf = "Girlsname"

# %%
len(gf)
# Out:
# 9

# %%
gf[0:2]
# Out:
# 'Gi'

# %%
man = "Khurkhuri Laal"

# %%
man[0:-1]
# Out:
# 'Khurkhuri Laa'

# %%
man[0:-1] == man[0:-1+len(man)]
# Out:
# True
